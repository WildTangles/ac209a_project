# %%
#imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import numpy as np
import pandas as pd
import pickle
# %matplotlib inline

# %%
# dictionary to translate numeric codes to state abbrev. names
state_codes = {  
1: "AL", 2: "AK",4: "AZ",5: "AR",6: "CA",8: "CO",9: "CT",10: "DE",
11: "DC",12: "FL",13: "GA",15: "HI",16: "ID",17: "IL",18: "IN",19: "IA",
20: "KS",21: "KY",22: "LA",23: "ME",24: "MD",25: "MA",26: "MI",27: "MN",
28: "MS",29: "MO",30: "MT",31: "NE",32: "NV",33: "NH",34: "NJ",35: "NM",
36: "NY",37: "NC",38: "ND",39: "OH",40: "OK",41: "OR",42: "PA",44: "RI",
45: "SC",46: "SD",47: "TN",48: "TX",49: "UT",50: "VT",51: "VA",53: "WA",
54: "WV",55: "WI",56: "WY"}

# %%
# raw ACS data file paths
path10 = 'Datasets/demographics/ACS_10_1YR_S0201_with_ann.csv'
path12 = 'Datasets/demographics/ACS_12_1YR_S0201_with_ann.csv'
path14 = 'Datasets/demographics/ACS_14_1YR_S0201_with_ann.csv'
path16 = 'Datasets/demographics/ACS_16_1YR_S0201_with_ann.csv'
path17 = 'Datasets/demographics/ACS_17_1YR_S0201_with_ann.csv'

# read in the raw files
df10 = pd.read_csv(path10, header = 1)
df12 = pd.read_csv(path12, header = 1)
df14 = pd.read_csv(path14, header = 1)
df16 = pd.read_csv(path16, header = 1)
df17 = pd.read_csv(path17, header = 1)

# %%
def clean(df, year):

    # insert year column
    df.insert(0, 'year', year)

    # insert state column (as 2-char code, like: MA)
    df.insert(1, 'state', df.Id2.apply(lambda x: int(x / 100)))
    df.state = df.state.apply(lambda x: state_codes[x])
    
    # insert district column, as an integer
    # districts should start with district 1, not 0
    df.insert(2, 'district', df.Id2.apply(lambda x: int(str(x)[-2:])))
    df.district = df.district.replace(0, 1)

    # filter out Margin of Error columns
    columns_to_keep = [col for col in df.columns if not 'Margin of Error;' in col]
    df = df[columns_to_keep]
    
    # create index as: state_district_year
    df.index = ['{0}_{1:02d}_{2}'.format(row['state'], row['district'], row['year']) for _,row in df.iterrows()]
    
    return df

# %%
acs10 = clean(df10, 2010)
acs12 = clean(df12, 2012)
acs14 = clean(df14, 2014)
acs16 = clean(df16, 2016)
acs17 = clean(df17, 2017)

# %%
# check order of unemployement columns
[col for col in acs10.columns if 'EMPLOYMENT STATUS - In labor force - Civilian labor force - Unemployed' in col]
# Out:
# ['Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Unemployed',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Unemployed - Percent of civilian labor force',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Unemployed.1',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Unemployed - Percent of civilian labor force.1']

# %%
len(acs17.columns)
# Out:
# 316

# %%
# find the common set of columns between two dataframes
len(set(acs16.columns).intersection(set(acs17.columns)))
# Out:
# 287

# %%
set(acs10.columns).intersection(set(acs12.columns))
# Out:
# {'Estimate; CLASS OF WORKER - Civilian employed population 16 years and over',
#  'Estimate; CLASS OF WORKER - Government workers',
#  'Estimate; CLASS OF WORKER - Private wage and salary workers',
#  'Estimate; CLASS OF WORKER - Self-employed workers in own not incorporated business',
#  'Estimate; CLASS OF WORKER - Unpaid family workers',
#  'Estimate; COMMUTING TO WORK - Car, truck, or van - carpooled',
#  'Estimate; COMMUTING TO WORK - Car, truck, or van - drove alone',
#  'Estimate; COMMUTING TO WORK - Mean travel time to work (minutes)',
#  'Estimate; COMMUTING TO WORK - Other means',
#  'Estimate; COMMUTING TO WORK - Public transportation (excluding taxicab)',
#  'Estimate; COMMUTING TO WORK - Walked',
#  'Estimate; COMMUTING TO WORK - Worked at home',
#  'Estimate; COMMUTING TO WORK - Workers 16 years and over',
#  'Estimate; DISABILITY STATUS - Civilian noninstitutionalized population 18 to 64 years',
#  'Estimate; DISABILITY STATUS - Civilian noninstitutionalized population 65 years and older',
#  'Estimate; DISABILITY STATUS - Civilian noninstitutionalized population under 18 years',
#  'Estimate; DISABILITY STATUS - Total civilian noninstitutionalized population',
#  'Estimate; DISABILITY STATUS - With a disability',
#  'Estimate; DISABILITY STATUS - With a disability.1',
#  'Estimate; DISABILITY STATUS - With a disability.2',
#  'Estimate; DISABILITY STATUS - With a disability.3',
#  "Estimate; EDUCATIONAL ATTAINMENT - Bachelor's degree",
#  "Estimate; EDUCATIONAL ATTAINMENT - Bachelor's degree or higher",
#  "Estimate; EDUCATIONAL ATTAINMENT - Female, bachelor's degree or higher",
#  'Estimate; EDUCATIONAL ATTAINMENT - Female, high school graduate or higher',
#  'Estimate; EDUCATIONAL ATTAINMENT - Graduate or professional degree',
#  'Estimate; EDUCATIONAL ATTAINMENT - High school graduate (includes equivalency)',
#  'Estimate; EDUCATIONAL ATTAINMENT - High school graduate or higher',
#  'Estimate; EDUCATIONAL ATTAINMENT - Less than high school diploma',
#  "Estimate; EDUCATIONAL ATTAINMENT - Male, bachelor's degree or higher",
#  'Estimate; EDUCATIONAL ATTAINMENT - Male, high school graduate or higher',
#  'Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over',
#  "Estimate; EDUCATIONAL ATTAINMENT - Some college or associate's degree",
#  'Estimate; EMPLOYMENT STATUS - Females 16 years and over',
#  'Estimate; EMPLOYMENT STATUS - In labor force',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Armed Forces',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Employed',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Employed.1',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Unemployed',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Unemployed - Percent of civilian labor force',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Unemployed - Percent of civilian labor force.1',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Unemployed.1',
#  'Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force.1',
#  'Estimate; EMPLOYMENT STATUS - In labor force.1',
#  'Estimate; EMPLOYMENT STATUS - Not in labor force',
#  'Estimate; EMPLOYMENT STATUS - Population 16 years and over',
#  'Estimate; FERTILITY - Women 15 to 50 years',
#  'Estimate; FERTILITY - Women 15 to 50 years who had a birth in the past 12 months',
#  'Estimate; FERTILITY - Women 15 to 50 years who had a birth in the past 12 months - Unmarried women 15 to 50 years who had a birth in the past 12 months',
#  'Estimate; FERTILITY - Women 15 to 50 years who had a birth in the past 12 months - Unmarried women 15 to 50 years who had a birth in the past 12 months - As a percent of all women with a birth in the past 12 months',
#  'Estimate; GROSS RENT - Median gross rent (dollars)',
#  'Estimate; GROSS RENT - Occupied units paying rent',
#  'Estimate; GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more',
#  'Estimate; GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent',
#  'Estimate; GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Occupied units paying rent (excluding units where GRAPI cannot be computed)',
#  'Estimate; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population',
#  'Estimate; HEALTH INSURANCE COVERAGE - No health insurance coverage',
#  'Estimate; HEALTH INSURANCE COVERAGE - With private health insurance',
#  'Estimate; HEALTH INSURANCE COVERAGE - With public coverage',
#  'Estimate; HOUSE HEATING FUEL - All other fuels',
#  'Estimate; HOUSE HEATING FUEL - Electricity',
#  'Estimate; HOUSE HEATING FUEL - Gas',
#  'Estimate; HOUSE HEATING FUEL - No fuel used',
#  'Estimate; HOUSE HEATING FUEL - Occupied housing units',
#  'Estimate; HOUSEHOLDS BY TYPE - Average family size',
#  'Estimate; HOUSEHOLDS BY TYPE - Average household size',
#  'Estimate; HOUSEHOLDS BY TYPE - Family households',
#  'Estimate; HOUSEHOLDS BY TYPE - Family households - Female householder, no husband present, family',
#  'Estimate; HOUSEHOLDS BY TYPE - Family households - Female householder, no husband present, family - With own children under 18 years',
#  'Estimate; HOUSEHOLDS BY TYPE - Family households - Married-couple family',
#  'Estimate; HOUSEHOLDS BY TYPE - Family households - Married-couple family - With own children under 18 years',
#  'Estimate; HOUSEHOLDS BY TYPE - Family households - With own children under 18 years',
#  'Estimate; HOUSEHOLDS BY TYPE - Households',
#  'Estimate; HOUSEHOLDS BY TYPE - Nonfamily households',
#  'Estimate; HOUSEHOLDS BY TYPE - Nonfamily households - Female householder',
#  'Estimate; HOUSEHOLDS BY TYPE - Nonfamily households - Female householder - Living alone',
#  'Estimate; HOUSEHOLDS BY TYPE - Nonfamily households - Female householder - Not living alone',
#  'Estimate; HOUSEHOLDS BY TYPE - Nonfamily households - Male householder',
#  'Estimate; HOUSEHOLDS BY TYPE - Nonfamily households - Male householder - Living alone',
#  'Estimate; HOUSEHOLDS BY TYPE - Nonfamily households - Male householder - Not living alone',
#  'Estimate; HOUSING TENURE - Average household size of owner-occupied unit',
#  'Estimate; HOUSING TENURE - Average household size of renter-occupied unit',
#  'Estimate; HOUSING TENURE - Occupied housing units',
#  'Estimate; HOUSING TENURE - Owner-occupied housing units',
#  'Estimate; HOUSING TENURE - Renter-occupied housing units',
#  'Estimate; INDUSTRY - Agriculture, forestry, fishing and hunting, and mining',
#  'Estimate; INDUSTRY - Arts, entertainment, and recreation, and accommodation and food services',
#  'Estimate; INDUSTRY - Civilian employed population 16 years and over',
#  'Estimate; INDUSTRY - Construction',
#  'Estimate; INDUSTRY - Educational services, and health care and social assistance',
#  'Estimate; INDUSTRY - Finance and insurance, and real estate and rental and leasing',
#  'Estimate; INDUSTRY - Information',
#  'Estimate; INDUSTRY - Manufacturing',
#  'Estimate; INDUSTRY - Other services (except public administration)',
#  'Estimate; INDUSTRY - Professional, scientific, and management, and administrative and waste management services',
#  'Estimate; INDUSTRY - Public administration',
#  'Estimate; INDUSTRY - Retail trade',
#  'Estimate; INDUSTRY - Transportation and warehousing, and utilities',
#  'Estimate; INDUSTRY - Wholesale trade',
#  'Estimate; LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH - English only',
#  'Estimate; LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH - Language other than English',
#  'Estimate; LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH - Language other than English - Speak English less than "very well"',
#  'Estimate; LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH - Population 5 years and over',
#  'Estimate; MARITAL STATUS - Divorced',
#  'Estimate; MARITAL STATUS - Divorced.1',
#  'Estimate; MARITAL STATUS - Divorced.2',
#  'Estimate; MARITAL STATUS - Female 15 years and over',
#  'Estimate; MARITAL STATUS - Male 15 years and over',
#  'Estimate; MARITAL STATUS - Never married',
#  'Estimate; MARITAL STATUS - Never married.1',
#  'Estimate; MARITAL STATUS - Never married.2',
#  'Estimate; MARITAL STATUS - Now married, except separated',
#  'Estimate; MARITAL STATUS - Now married, except separated.1',
#  'Estimate; MARITAL STATUS - Now married, except separated.2',
#  'Estimate; MARITAL STATUS - Population 15 years and over',
#  'Estimate; MARITAL STATUS - Separated',
#  'Estimate; MARITAL STATUS - Separated.1',
#  'Estimate; MARITAL STATUS - Separated.2',
#  'Estimate; MARITAL STATUS - Widowed',
#  'Estimate; MARITAL STATUS - Widowed.1',
#  'Estimate; MARITAL STATUS - Widowed.2',
#  'Estimate; OCCUPATION - Civilian employed population 16 years and over',
#  'Estimate; OCCUPATION - Female civilian employed population 16 years and over',
#  'Estimate; OCCUPATION - Male civilian employed population 16 years and over',
#  'Estimate; OCCUPATION - Management, business, science, and arts occupations',
#  'Estimate; OCCUPATION - Management, business, science, and arts occupations.1',
#  'Estimate; OCCUPATION - Management, business, science, and arts occupations.2',
#  'Estimate; OCCUPATION - Natural resources, construction, and maintenance occupations',
#  'Estimate; OCCUPATION - Natural resources, construction, and maintenance occupations.1',
#  'Estimate; OCCUPATION - Natural resources, construction, and maintenance occupations.2',
#  'Estimate; OCCUPATION - Production, transportation, and material moving occupations',
#  'Estimate; OCCUPATION - Production, transportation, and material moving occupations.1',
#  'Estimate; OCCUPATION - Production, transportation, and material moving occupations.2',
#  'Estimate; OCCUPATION - Sales and office occupations',
#  'Estimate; OCCUPATION - Sales and office occupations.1',
#  'Estimate; OCCUPATION - Sales and office occupations.2',
#  'Estimate; OCCUPATION - Service occupations',
#  'Estimate; OCCUPATION - Service occupations.1',
#  'Estimate; OCCUPATION - Service occupations.2',
#  'Estimate; OWNER CHARACTERISTICS - Median selected monthly owner costs with a mortgage (dollars)',
#  'Estimate; OWNER CHARACTERISTICS - Median selected monthly owner costs without a mortgage (dollars)',
#  'Estimate; OWNER CHARACTERISTICS - Median value (dollars)',
#  'Estimate; OWNER CHARACTERISTICS - Owner-occupied housing units',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Female',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Female.1',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Female.2',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Female.3',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Foreign born',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Foreign born; naturalized U.S. citizen',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Foreign born; not a U.S. citizen',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Male',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Male.1',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Male.2',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Male.3',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Native',
#  'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Population born outside the United States',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - 18 to 64 years',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - 18 years and over',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - 65 years and over',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - All families',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - All families - With related children under 18 years',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - All families - With related children under 18 years - With related children under 5 years only',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - All people',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Female householder, no husband present, family',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Female householder, no husband present, family - With related children under 18 years',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Female householder, no husband present, family - With related children under 18 years - With related children under 5 years only',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Married-couple family',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Married-couple family - With related children under 18 years',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Married-couple family - With related children under 18 years - With related children under 5 years only',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - People in families',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Under 18 years',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Under 18 years - Related children under 18 years',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Under 18 years - Related children under 18 years - Related children 5 to 17 years',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Under 18 years - Related children under 18 years - Related children under 5 years',
#  'Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - Unrelated individuals 15 years and over',
#  'Estimate; RELATIONSHIP - Child',
#  'Estimate; RELATIONSHIP - Householder or spouse',
#  'Estimate; RELATIONSHIP - Nonrelatives',
#  'Estimate; RELATIONSHIP - Nonrelatives - Unmarried partner',
#  'Estimate; RELATIONSHIP - Other relatives',
#  'Estimate; RELATIONSHIP - Population in households',
#  'Estimate; RESIDENCE 1 YEAR AGO - Abroad',
#  'Estimate; RESIDENCE 1 YEAR AGO - Different house in the U.S.',
#  'Estimate; RESIDENCE 1 YEAR AGO - Different house in the U.S. - Different county',
#  'Estimate; RESIDENCE 1 YEAR AGO - Different house in the U.S. - Different county - Different state',
#  'Estimate; RESIDENCE 1 YEAR AGO - Different house in the U.S. - Different county - Same state',
#  'Estimate; RESIDENCE 1 YEAR AGO - Different house in the U.S. - Same county',
#  'Estimate; RESIDENCE 1 YEAR AGO - Population 1 year and over',
#  'Estimate; RESIDENCE 1 YEAR AGO - Same house',
#  'Estimate; RESPONSIBILITY FOR GRANDCHILDREN UNDER 18 YEARS - Living with grandchild(ren)',
#  'Estimate; RESPONSIBILITY FOR GRANDCHILDREN UNDER 18 YEARS - Living with grandchild(ren) - Responsible for grandchild(ren)',
#  'Estimate; RESPONSIBILITY FOR GRANDCHILDREN UNDER 18 YEARS - Population 30 years and over',
#  'Estimate; SCHOOL ENROLLMENT - College or graduate school',
#  'Estimate; SCHOOL ENROLLMENT - Elementary school (grades 1-8)',
#  'Estimate; SCHOOL ENROLLMENT - High school (grades 9-12)',
#  'Estimate; SCHOOL ENROLLMENT - Kindergarten',
#  'Estimate; SCHOOL ENROLLMENT - Male 3 years and over enrolled in school',
#  'Estimate; SCHOOL ENROLLMENT - Nursery school, preschool',
#  'Estimate; SCHOOL ENROLLMENT - Percent enrolled in college or graduate school',
#  'Estimate; SCHOOL ENROLLMENT - Percent enrolled in college or graduate school - Female 3 years and over enrolled in school',
#  'Estimate; SCHOOL ENROLLMENT - Percent enrolled in college or graduate school.1',
#  'Estimate; SCHOOL ENROLLMENT - Percent enrolled in kindergarten to grade 12',
#  'Estimate; SCHOOL ENROLLMENT - Percent enrolled in kindergarten to grade 12.1',
#  'Estimate; SCHOOL ENROLLMENT - Population 3 years and over enrolled in school',
#  'Estimate; SELECTED CHARACTERISTICS - 1.01 or more occupants per room',
#  'Estimate; SELECTED CHARACTERISTICS - No telephone service available',
#  'Estimate; SELECTED CHARACTERISTICS - Occupied housing units',
#  'Estimate; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more',
#  'Estimate; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Housing units with a mortgage (excluding units where SMOC cannot be computed)',
#  'Estimate; SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent',
#  'Estimate; SEX AND AGE - 18 to 24 years',
#  'Estimate; SEX AND AGE - 18 to 34 years',
#  'Estimate; SEX AND AGE - 18 years and over',
#  'Estimate; SEX AND AGE - 18 years and over.1',
#  'Estimate; SEX AND AGE - 21 years and over',
#  'Estimate; SEX AND AGE - 25 to 34 years',
#  'Estimate; SEX AND AGE - 35 to 44 years',
#  'Estimate; SEX AND AGE - 35 to 64 years',
#  'Estimate; SEX AND AGE - 45 to 54 years',
#  'Estimate; SEX AND AGE - 5 to 17 years',
#  'Estimate; SEX AND AGE - 55 to 64 years',
#  'Estimate; SEX AND AGE - 62 years and over',
#  'Estimate; SEX AND AGE - 65 to 74 years',
#  'Estimate; SEX AND AGE - 65 years and over',
#  'Estimate; SEX AND AGE - 65 years and over.1',
#  'Estimate; SEX AND AGE - 75 years and over',
#  'Estimate; SEX AND AGE - Female',
#  'Estimate; SEX AND AGE - Female.1',
#  'Estimate; SEX AND AGE - Female.2',
#  'Estimate; SEX AND AGE - Female.3',
#  'Estimate; SEX AND AGE - Female.4',
#  'Estimate; SEX AND AGE - Female.5',
#  'Estimate; SEX AND AGE - Male',
#  'Estimate; SEX AND AGE - Male.1',
#  'Estimate; SEX AND AGE - Male.2',
#  'Estimate; SEX AND AGE - Male.3',
#  'Estimate; SEX AND AGE - Male.4',
#  'Estimate; SEX AND AGE - Male.5',
#  'Estimate; SEX AND AGE - Median age (years)',
#  'Estimate; SEX AND AGE - Total population',
#  'Estimate; SEX AND AGE - Under 18 years',
#  'Estimate; SEX AND AGE - Under 5 years',
#  'Estimate; TOTAL NUMBER OF RACES REPORTED - Four or more races',
#  'Estimate; TOTAL NUMBER OF RACES REPORTED - One race',
#  'Estimate; TOTAL NUMBER OF RACES REPORTED - Three races',
#  'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population',
#  'Estimate; TOTAL NUMBER OF RACES REPORTED - Two races',
#  'Estimate; UNITS IN STRUCTURE - 1-unit, detached or attached',
#  'Estimate; UNITS IN STRUCTURE - 2 to 4 units',
#  'Estimate; UNITS IN STRUCTURE - 5 or more units',
#  'Estimate; UNITS IN STRUCTURE - Mobile home, boat, RV, van, etc.',
#  'Estimate; UNITS IN STRUCTURE - Occupied housing units',
#  'Estimate; VEHICLES AVAILABLE - 1 or more',
#  'Estimate; VEHICLES AVAILABLE - None',
#  'Estimate; VEHICLES AVAILABLE - Occupied housing units',
#  'Estimate; VETERAN STATUS - Civilian population 18 years and over',
#  'Estimate; VETERAN STATUS - Civilian veteran',
#  'Estimate; WORLD REGION OF BIRTH OF FOREIGN BORN - Africa',
#  'Estimate; WORLD REGION OF BIRTH OF FOREIGN BORN - Asia',
#  'Estimate; WORLD REGION OF BIRTH OF FOREIGN BORN - Europe',
#  'Estimate; WORLD REGION OF BIRTH OF FOREIGN BORN - Foreign-born population excluding population born at sea',
#  'Estimate; WORLD REGION OF BIRTH OF FOREIGN BORN - Latin America',
#  'Estimate; WORLD REGION OF BIRTH OF FOREIGN BORN - Northern America',
#  'Estimate; WORLD REGION OF BIRTH OF FOREIGN BORN - Oceania',
#  'Estimate; YEAR STRUCTURE BUILT - Built 1939 or earlier',
#  'Estimate; YEAR STRUCTURE BUILT - Built 1940 to 1959',
#  'Estimate; YEAR STRUCTURE BUILT - Built 1960 to 1979',
#  'Estimate; YEAR STRUCTURE BUILT - Occupied housing units',
#  'Geography',
#  'Id',
#  'Id.1',
#  'Id2',
#  'Population Group',
#  'district',
#  'state',
#  'year'}

# %%
#[col for col in df.columns if not 'Margin of Error;' in col]

# %%
# 2010 and 2012
raw_predictor_name_subset_10_12 = [
"Estimate; SEX AND AGE - Female",
"Estimate; SEX AND AGE - 18 to 24 years",
"Estimate; SEX AND AGE - 25 to 34 years",
"Estimate; SEX AND AGE - Median age (years)",
"Estimate; RELATIONSHIP - Nonrelatives - Unmarried partner",
"Estimate; HOUSEHOLDS BY TYPE - Nonfamily households - Male householder - Living alone",
"Estimate; EDUCATIONAL ATTAINMENT - Bachelor's degree or higher",
"Estimate; FERTILITY - Women 15 to 50 years who had a birth in the past 12 months - Unmarried women 15 to 50 years who had a birth in the past 12 months - As a percent of all women with a birth in the past 12 months",
"Estimate; VETERAN STATUS - Civilian veteran",
"Estimate; RESIDENCE 1 YEAR AGO - Same house",
"Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Native",
"Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Foreign born",
"Estimate; WORLD REGION OF BIRTH OF FOREIGN BORN - Latin America",
"Estimate; LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH - Language other than English",
"Estimate; EMPLOYMENT STATUS - In labor force - Civilian labor force - Unemployed",
"Estimate; COMMUTING TO WORK - Public transportation (excluding taxicab)",
"Estimate; HEALTH INSURANCE COVERAGE - No health insurance coverage",
"Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - All people",
"Estimate; OWNER CHARACTERISTICS - Median value (dollars)"] 

raw_predictor_name_supplement_10 = [
"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) - Median household income (dollars)",
"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) - With Food Stamp/SNAP benefits"]

raw_predictor_name_supplement_12 = [
"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2012 INFLATION-ADJUSTED DOLLARS) - Median household income (dollars)",
"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2012 INFLATION-ADJUSTED DOLLARS) - With Food Stamp/SNAP benefits"]

raw_predictor_names_10 = raw_predictor_name_subset_10_12 + raw_predictor_name_supplement_10
raw_predictor_names_12 = raw_predictor_name_subset_10_12 + raw_predictor_name_supplement_12


# 2014 and beyond
raw_predictor_name_subset_14_beyond = [
"Estimate; SEX AND AGE - Total population - Female",
"Estimate; SEX AND AGE - 18 to 24 years",
"Estimate; SEX AND AGE - 25 to 34 years",
"Estimate; SEX AND AGE - Median age (years)",
"Estimate; RELATIONSHIP - Population in households - Nonrelatives - Unmarried partner",
"Estimate; HOUSEHOLDS BY TYPE - Households - Nonfamily households - Male householder - Living alone",
"Estimate; EDUCATIONAL ATTAINMENT - Bachelor's degree or higher",
"Estimate; FERTILITY - Women 15 to 50 years - Women 15 to 50 years who had a birth in the past 12 months - Unmarried women 15 to 50 years who had a birth in the past 12 months - As a percent of all women with a birth in the past 12 months",
"Estimate; VETERAN STATUS - Civilian population 18 years and over - Civilian veteran",
"Estimate; RESIDENCE 1 YEAR AGO - Population 1 year and over - Same house",
"Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Native",
"Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Foreign born",
"Estimate; WORLD REGION OF BIRTH OF FOREIGN BORN - Foreign-born population excluding population born at sea - Latin America",
"Estimate; LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH - Population 5 years and over - Language other than English",
"Estimate; EMPLOYMENT STATUS - Population 16 years and over - In labor force - Civilian labor force - Unemployed",
"Estimate; COMMUTING TO WORK - Workers 16 years and over - Public transportation (excluding taxicab)",
"Estimate; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population - No health insurance coverage",
"Estimate; POVERTY RATES FOR FAMILIES AND PEOPLE FOR WHOM POVERTY STATUS IS DETERMINED - All people",
"Estimate; OWNER CHARACTERISTICS - Owner-occupied housing units - Median value (dollars)"]

raw_predictor_name_supplement_14 = [
"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2014 INFLATION-ADJUSTED DOLLARS) - Households - Median household income (dollars)",
"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2014 INFLATION-ADJUSTED DOLLARS) - With Food Stamp/SNAP benefits"]

raw_predictor_name_supplement_16 = [
"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Households - Median household income (dollars)",
"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) - With Food Stamp/SNAP benefits"]

raw_predictor_name_supplement_17 = [
"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Households - Median household income (dollars)",
"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) - With Food Stamp/SNAP benefits"]

raw_predictor_names_14 = raw_predictor_name_subset_14_beyond + raw_predictor_name_supplement_14
raw_predictor_names_16 = raw_predictor_name_subset_14_beyond + raw_predictor_name_supplement_16
raw_predictor_names_17 = raw_predictor_name_subset_14_beyond + raw_predictor_name_supplement_17

# %%
renamed_predictors = [
"female_pct",
"age18_24_pct",
"age25_34_pct",
"median_age",
"unmarried_partner_pct",
"male_living_alone_pct",
"bachelors_deg_or_higher_pct",
"past_year_births_to_unmarried_women_pct",
"civilian_veteran_pct",
"live_same_house_past_year_pct",
"native_born_population",
"foreign_born_population",
"foreign_born_proportion_from_LatinAmerica",
"speak_other_language_at_home_pct",
"labor_force_unemployed_pct",
"public_transit_commuter_pct",
"no_health_insurance_pct",
"poverty_rate_pct",
"median_housing_value",
"median_household_income",
"food_stamp_benefits_pct"]

# %%
# check number of predictors
len(acs17[raw_predictor_names_17].columns)
# Out:
# 21

# %%
identifier_cols = ['state', 'district', 'year']

acs10 = acs10[['state', 'district', 'year'] + raw_predictor_names_10]
acs12 = acs12[['state', 'district', 'year'] + raw_predictor_names_12]
acs14 = acs14[['state', 'district', 'year'] + raw_predictor_names_14]
acs16 = acs16[['state', 'district', 'year'] + raw_predictor_names_16]
acs17 = acs17[['state', 'district', 'year'] + raw_predictor_names_17]

# %%
acs10.columns = identifier_cols + renamed_predictors
acs10.head()
# Out:
#            state  district  year  female_pct  age18_24_pct  age25_34_pct  \
# AL_01_2010    AL         1  2010        51.0           9.0          12.3
# AL_02_2010    AL         2  2010        52.1          10.1          12.6
# AL_03_2010    AL         3  2010        51.7          12.5          12.1
# AL_04_2010    AL         4  2010        50.6           8.4          11.3
# AL_05_2010    AL         5  2010        51.0           9.8          12.4
#
#             median_age  unmarried_partner_pct  male_living_alone_pct  \
# AL_01_2010        38.4                    1.6                   12.3
# AL_02_2010        37.7                    1.7                   12.3
# AL_03_2010        36.7                    1.6                   12.8
# AL_04_2010        40.2                    1.2                   10.6
# AL_05_2010        38.3                    1.2                   12.3
#
#             bachelors_deg_or_higher_pct           ...             \
# AL_01_2010                         21.5           ...
# AL_02_2010                         20.1           ...
# AL_03_2010                         19.9           ...
# AL_04_2010                         12.1           ...
# AL_05_2010                         26.9           ...
#
#             foreign_born_population  \
# AL_01_2010                    22296
# AL_02_2010                    16268
# AL_03_2010                    22689
# AL_04_2010                    26109
# AL_05_2010                    31009
#
#             foreign_born_proportion_from_LatinAmerica  \
# AL_01_2010                                       45.1
# AL_02_2010                                       49.5
# AL_03_2010                                       45.2
# AL_04_2010                                       87.5
# AL_05_2010                                       53.8
#
#             speak_other_language_at_home_pct  labor_force_unemployed_pct  \
# AL_01_2010                               4.9                         7.5
# AL_02_2010                               3.7                         5.5
# AL_03_2010                               5.0                         7.9
# AL_04_2010                               5.8                         7.4
# AL_05_2010                               6.0                         7.0
#
#             public_transit_commuter_pct  no_health_insurance_pct  \
# AL_01_2010                          0.4                     17.3
# AL_02_2010                          0.2                     12.9
# AL_03_2010                          0.5                     14.9
# AL_04_2010                          0.1                     16.3
# AL_05_2010                          0.3                     13.1
#
#             poverty_rate_pct  median_housing_value  median_household_income  \
# AL_01_2010              19.1                136000                    41172
# AL_02_2010              18.6                111200                    40567
# AL_03_2010              24.0                110100                    35452
# AL_04_2010              19.8                 93400                    36715
# AL_05_2010              15.3                135600                    45856
#
#             food_stamp_benefits_pct
# AL_01_2010                     15.7
# AL_02_2010                     15.3
# AL_03_2010                     17.2
# AL_04_2010                     14.6
# AL_05_2010                     10.6
#
# [5 rows x 24 columns]

# %%
# convert foreign / native born population to ratio
for df in [acs10, acs12, acs14, acs16, acs17]:
    df.columns = identifier_cols + renamed_predictors
    df['foreign_to_native_born_ratio'] = df['foreign_born_population'] / df['native_born_population']
    df.drop(['native_born_population', 'foreign_born_population'], axis = 1, inplace = True)

# %%
# use 2017 demographics as 2018 data
acs18 = acs17
acs18.year = 2018
acs18.index = ['{0}_{1:02d}_{2}'.format(row['state'], row['district'], row['year']) for _,row in df.iterrows()]

# %%
acs18
# Out:
#            state  district  year  female_pct  age18_24_pct  age25_34_pct  \
# AL_01_2018    AL         1  2018        51.8           8.2          12.9
# AL_02_2018    AL         2  2018        51.2           9.7          13.0
# AL_03_2018    AL         3  2018        51.2          10.7          13.0
# AL_04_2018    AL         4  2018        51.4           8.8          11.7
# AL_05_2018    AL         5  2018        50.8           9.3          13.2
# AL_06_2018    AL         6  2018        52.3           8.6          12.3
# AL_07_2018    AL         7  2018        52.3          12.5          14.2
# AK_01_2018    AK         1  2018        47.9           9.9          16.0
# AZ_01_2018    AZ         1  2018        49.5          10.7          12.2
# AZ_02_2018    AZ         2  2018        50.5           9.5          12.8
# AZ_03_2018    AZ         3  2018        50.0          13.1          14.1
# AZ_04_2018    AZ         4  2018        49.6           7.0          10.5
# AZ_03_2018                         16.8              ...
# AZ_04_2018                         19.3              ...
# AZ_05_2018                         36.0              ...
# AZ_06_2018                         44.4              ...
# AZ_07_2018                         13.8              ...
# AZ_08_2018                         30.7              ...
# AZ_09_2018                         39.7              ...
# AR_01_2018                         16.4              ...
# AR_02_2018                         30.5              ...
# AR_03_2018                         28.8              ...
# AR_04_2018                         17.2              ...
# CA_01_2018                         24.8              ...
# CA_02_2018                         42.3              ...
# CA_03_2018                         25.1              ...
# CA_04_2018                         32.9              ...
# CA_05_2018                         32.4              ...
# CA_06_2018                         28.4              ...
# CA_07_2018                         33.4              ...
# CA_08_2018                         15.9              ...
# CA_09_2018                         21.3              ...
# ...                                 ...              ...
# VA_04_2018                         29.8              ...
# VA_05_2018                         29.1              ...
# VA_06_2018                         27.3              ...
# VA_07_2018                         40.3              ...
# VA_08_2018                         62.2              ...
# VA_09_2018                         19.9              ...
# VA_10_2018                         56.1              ...
# VA_11_2018                         56.8              ...
# WA_01_2018                         43.2              ...
# WA_02_2018                         32.5              ...
# WA_03_2018                         27.1              ...
# WA_04_2018                         20.6              ...
# WA_05_2018                         29.8              ...
# WA_06_2018                         30.1              ...
# WA_07_2018                         60.5              ...
# WA_08_2018                         34.0              ...
# WA_09_2018                         43.0              ...
# WA_10_2018                         28.2              ...
# WV_01_2018                         23.1              ...
# WV_02_2018                         21.1              ...
# WV_03_2018                         16.2              ...
# WI_01_2018                         29.8              ...
# WI_02_2018                         42.3              ...
# WI_03_2018                         26.0              ...
# WI_04_2018                         27.6              ...
# WI_05_2018                         38.2              ...
# WI_06_2018                         26.8              ...
# WI_07_2018                         23.8              ...
# WI_08_2018                         27.8              ...
# WY_01_2018                         27.6              ...
#
#             foreign_born_proportion_from_LatinAmerica  \
# AL_01_2018                                       38.3
# AL_02_2018                                       41.6
# AL_03_2018                                       34.7
# AL_04_2018                                       76.4
# AL_05_2018                                       43.6
# AL_06_2018                                       44.7
# AL_07_2018                                       49.8
# AK_01_2018                                       14.9
# AZ_01_2018                                       54.4
# AZ_02_2018                                       53.3
# AZ_03_2018                                       88.1
# AZ_04_2018                                       57.4
# AZ_05_2018                                       40.4
# AZ_06_2018                                       37.1
# AZ_07_2018                                       83.0
# AZ_08_2018                                       33.1
# AZ_09_2018                                       52.3
# AR_01_2018                                       48.4
# AR_02_2018                                       47.5
# AR_03_2018                                       63.5
# AR_04_2018                                       73.5
# CA_01_2018                                       47.0
# CA_02_2018                                       49.3
# CA_03_2018                                       50.9
# CA_04_2018                                       26.8
# CA_05_2018                                       54.3
# CA_06_2018                                       35.9
# CA_07_2018                                       21.8
# CA_08_2018                                       71.3
# CA_09_2018                                       50.0
# ...                                               ...
# VA_04_2018                                       46.3
# VA_05_2018                                       26.1
# VA_06_2018                                       37.3
# VA_07_2018                                       34.5
# VA_08_2018                                       36.7
# VA_09_2018                                       34.7
# VA_10_2018                                       32.6
# VA_11_2018                                       32.2
# WA_01_2018                                       17.4
# WA_02_2018                                       25.3
# WA_03_2018                                       33.1
# VA_08_2018                      4.1                      0.429607
# VA_09_2018                     12.7                      0.024698
# VA_10_2018                      3.6                      0.292002
# VA_11_2018                      4.2                      0.468530
# WA_01_2018                      7.4                      0.212037
# WA_02_2018                     11.6                      0.168070
# WA_03_2018                     15.1                      0.091600
# WA_04_2018                     19.5                      0.195030
# WA_05_2018                     14.7                      0.062476
# WA_06_2018                     13.4                      0.077029
# WA_07_2018                      6.9                      0.200763
# WA_08_2018                      9.9                      0.174837
# WA_09_2018                     12.7                      0.446990
# WA_10_2018                     13.5                      0.108490
# WV_01_2018                     13.4                      0.020443
# WV_02_2018                     15.3                      0.022722
# WV_03_2018                     21.6                      0.006728
# WI_01_2018                     10.9                      0.059500
# WI_02_2018                      8.2                      0.080907
# WI_03_2018                      9.9                      0.027031
# WI_04_2018                     21.8                      0.105170
# WI_05_2018                      6.1                      0.052795
# WI_06_2018                      9.5                      0.037647
# WI_07_2018                     10.8                      0.023095
# WI_08_2018                      8.2                      0.036511
# WY_01_2018                      6.3                      0.036722
#
# [436 rows x 23 columns]

# %%
# stack 5 dataframes from each year on top of each other
demographics_data = acs18.append([acs16, acs14, acs12, acs10])

# %%
demographics_data
# Out:
#            state  district  year  female_pct  age18_24_pct  age25_34_pct  \
# AL_01_2018    AL         1  2018        51.8           8.2          12.9
# AL_02_2018    AL         2  2018        51.2           9.7          13.0
# AL_03_2018    AL         3  2018        51.2          10.7          13.0
# AL_04_2018    AL         4  2018        51.4           8.8          11.7
# AL_05_2018    AL         5  2018        50.8           9.3          13.2
# AL_06_2018    AL         6  2018        52.3           8.6          12.3
# AL_07_2018    AL         7  2018        52.3          12.5          14.2
# AK_01_2018    AK         1  2018        47.9           9.9          16.0
# AZ_01_2018    AZ         1  2018        49.5          10.7          12.2
# AZ_02_2018    AZ         2  2018        50.5           9.5          12.8
# AZ_03_2018    AZ         3  2018        50.0          13.1          14.1
# AZ_04_2018    AZ         4  2018        49.6           7.0          10.5
# AZ_05_2018    AZ         5  2018        51.2           7.0          12.1
# AZ_06_2018    AZ         6  2018        51.0           6.9          13.9
# AZ_07_2018    AZ         7  2018        49.9          11.9          16.5
# AZ_08_2018    AZ         8  2018        52.0           7.7          11.9
# AZ_09_2018    AZ         9  2018        48.8          12.5          18.2
# AR_01_2018    AR         1  2018        50.2           8.6          12.0
# AR_02_2018    AR         2  2018        51.4           9.7          13.8
# AR_03_2018    AR         3  2018        50.3          10.5          13.8
# AR_04_2018    AR         4  2018        51.1           9.3          11.1
# CA_01_2018    CA         1  2018        49.6           9.4          12.3
# CA_02_2018    CA         2  2018        50.5           7.9          10.3
# CA_03_2018    CA         3  2018        49.7          12.1          14.3
# CA_04_2018    CA         4  2018        50.3           7.4          10.5
# CA_05_2018    CA         5  2018        51.4           8.7          14.1
# CA_06_2018    CA         6  2018        51.2           9.0          17.5
# CA_07_2018    CA         7  2018        51.1           8.2          14.1
# CA_08_2018    CA         8  2018        50.1          10.1          13.5
# CA_09_2018    CA         9  2018        50.7           9.2          13.5
# AZ_06_2018                              18.9                         2.8
# AZ_07_2018                              54.3                         4.5
# AZ_08_2018                              16.8                         2.6
# AZ_09_2018                              26.0                         3.3
# AR_01_2018                               3.0                         3.3
# AR_02_2018                               6.7                         3.0
# AR_03_2018                              13.6                         3.1
# AR_04_2018                               5.9                         3.5
# CA_01_2018                              11.2                         3.1
# CA_02_2018                              20.1                         3.0
# CA_03_2018                              31.9                         3.3
# CA_04_2018                              12.7                         2.5
# CA_05_2018                              33.2                         3.1
# CA_06_2018                              38.5                         4.9
# CA_07_2018                              28.2                         3.5
# CA_08_2018                              28.2                         5.3
# CA_09_2018                              39.0                         4.3
# ...                                      ...                         ...
# VA_03_2010                               7.8                         8.0
# VA_04_2010                               6.2                         5.0
# VA_05_2010                               5.2                         6.1
# VA_06_2010                               6.9                         5.0
# VA_07_2010                               9.5                         5.5
# VA_08_2010                              34.4                         4.0
# VA_09_2010                               3.4                         5.2
# VA_10_2010                              28.9                         4.1
# VA_11_2010                              34.4                         4.6
# WA_01_2010                              19.9                         6.8
# WA_02_2010                              12.7                         7.2
# WA_03_2010                              11.9                         8.2
# WA_04_2010                              31.0                         6.2
# WA_05_2010                               8.7                         6.3
# WA_06_2010                              12.6                         7.3
# WA_07_2010                              24.7                         6.8
# WA_08_2010                              21.3                         5.9
# WA_09_2010                              21.7                         7.7
# WV_01_2010                               2.5                         4.8
# WV_02_2010                               2.4                         5.2
# WV_03_2010                               1.8                         4.5
# WI_01_2010                               9.5                         6.9
# WI_02_2010                              10.5                         5.2
# WI_03_2010                               5.2                         4.7
# WI_04_2010                              18.3                         9.9
# WI_05_2010                               6.2                         5.2
# WI_06_2010                               5.9                         5.6
# WI_07_2010                               5.2                         5.9
# WI_08_2010                               6.5                         5.7
# WY_01_2010                               6.4                         4.2
#
#             public_transit_commuter_pct  no_health_insurance_pct  \
# AL_01_2018                          0.3                     10.5
# AL_02_2018                          0.1                      9.3
# AL_03_2018                          0.2                      8.9
# AL_04_2018                          0.2                     10.6
# AL_05_2018                          0.3                      9.0
# AL_06_2018                          0.2                      7.0
# AL_07_2018                          1.3                     10.4
# AK_01_2018                          1.7                     13.7
# AZ_01_2018                          0.7                     10.2
# AZ_02_2018                          2.2                      6.6
# AZ_03_2018                          1.9                     12.9
# AZ_04_2018                          0.6                      8.9
# AZ_05_2018                          0.9                      7.5
# AZ_06_2018                          1.5                      7.8
# AZ_07_2018                          4.4                     17.9
# AZ_08_2018                          0.7                      6.8
# AZ_09_2018                          2.8                     11.2
# AR_01_2018                          0.3                      6.9
# AR_02_2018                          0.4                      7.0
# AR_03_2018                          0.2                      9.7
# AR_04_2018                          0.3                      7.6
# CA_01_2018                          0.5                      5.9
# CA_02_2018                          4.3                      5.6
# CA_03_2018                          2.3                      5.3
# CA_04_2018                          1.5                      4.2
# CA_05_2018                          3.6                      6.1
# CA_06_2018                          2.9                      6.4
# CA_07_2018                          1.8                      4.7
# CA_08_2018                          1.1                      7.0
# CA_09_2018                          2.1                      6.2
# ...                                 ...                      ...
# VA_03_2010                          4.2                     16.0
demographics_data.to_csv('Datasets/demographics_data_2010_to_2018.csv')

# %%
demographics_data.columns
# Out:
# Index(['state', 'district', 'year', 'female_pct', 'age18_24_pct',
#        'age25_34_pct', 'median_age', 'unmarried_partner_pct',
#        'male_living_alone_pct', 'bachelors_deg_or_higher_pct',
#        'past_year_births_to_unmarried_women_pct', 'civilian_veteran_pct',
#        'live_same_house_past_year_pct',
#        'foreign_born_proportion_from_LatinAmerica',
#        'speak_other_language_at_home_pct', 'labor_force_unemployed_pct',
#        'public_transit_commuter_pct', 'no_health_insurance_pct',
#        'poverty_rate_pct', 'median_housing_value', 'median_household_income',
#        'food_stamp_benefits_pct', 'foreign_to_native_born_ratio'],
#       dtype='object')

# %%
fec = pickle.load(open('Datasets/data_FEC_NATIONALPOLL_2004_2018.p', 'rb'))

# %%
fec.index
# Out:
# Index(['AK_01_2004', 'AL_01_2004', 'AL_02_2004', 'AL_03_2004', 'AL_04_2004',
#        'AL_05_2004', 'AL_06_2004', 'AL_07_2004', 'AR_01_2004', 'AR_02_2004',
#        ...
#        'WV_03_2018', 'WI_01_2018', 'WI_02_2018', 'WI_03_2018', 'WI_04_2018',
#        'WI_05_2018', 'WI_06_2018', 'WI_07_2018', 'WI_08_2018', 'WY_01_2018'],
#       dtype='object', length=3431)

# %%
demographics_data = demographics_data.drop(['district', 'state', 'year'], axis=1)

# %%
# try joining FEC election data with ACS demographic data


fec_demographics_data = fec.join(demographics_data, how='inner')

# %%
set(fec_demographics_data['year'])
# Out:
# {2010, 2012, 2014, 2016, 2018}

# %%
# pickle.dump(fec_demographics_data, open('Datasets/data_FEC_NATIONALPOLL_DEMOGRAPHICS_2010_2018.p', 'wb'))
# fec_demographics_data.to_csv('Datasets/data_FEC_NATIONALPOLL_DEMOGRAPHICS_2010_2018.csv')
# test = pickle.load(open('Datasets/data_FEC_NATIONALPOLL_DEMOGRAPHICS_2010_2018.p', 'rb'))
# fec_demographics_data.shape, test.shape

# %%
fec.shape, demographics_data.shape
# Out:
# ((3431, 22), (2180, 20))

# %%
fec_demographics_imputed_data = fec.join(demographics_data, how='outer')

for index, row in fec_demographics_imputed_data.iterrows():
    if index not in fec.index:
        fec_demographics_imputed_data = fec_demographics_imputed_data[fec_demographics_imputed_data.index != index]
        
fec_demographics_imputed_data.shape
# Out:
# (3431, 42)

# %%
assert(sorted(fec_demographics_imputed_data.index) == sorted(fec.index))

# %%
demographics_data.columns
# Out:
# Index(['female_pct', 'age18_24_pct', 'age25_34_pct', 'median_age',
#        'unmarried_partner_pct', 'male_living_alone_pct',
#        'bachelors_deg_or_higher_pct',
#        'past_year_births_to_unmarried_women_pct', 'civilian_veteran_pct',
#        'live_same_house_past_year_pct',
#        'foreign_born_proportion_from_LatinAmerica',
#        'speak_other_language_at_home_pct', 'labor_force_unemployed_pct',
#        'public_transit_commuter_pct', 'no_health_insurance_pct',
#        'poverty_rate_pct', 'median_housing_value', 'median_household_income',
#        'food_stamp_benefits_pct', 'foreign_to_native_born_ratio'],
#       dtype='object')

# %%
for index, row in fec_demographics_imputed_data.iterrows():
    if row['year'] < 2010:
        impute_index = index[:-5] + '_2010'
        fec_demographics_imputed_data.loc[fec_demographics_imputed_data.index == index, demographics_data.columns] = fec_demographics_imputed_data[fec_demographics_imputed_data.index == impute_index][demographics_data.columns].values

# %%
fec_demographics_imputed_data[fec_demographics_imputed_data.index == 'AK_01_2010']
# Out:
#             district state    year       party candidatevotes totalvotes  \
# AK_01_2010       1.0    AK  2010.0  republican         175384     254335
#
#             candidate  national_poll  national_poll_prev  \
# AK_01_2010  Don Young      -2.622642            9.824324
#
#             national_poll_delta_subtract              ...               \
# AK_01_2010                    -12.446966              ...
#
#             foreign_born_proportion_from_LatinAmerica  \
# AK_01_2010                                       19.2
#
#            speak_other_language_at_home_pct  labor_force_unemployed_pct  \
# AK_01_2010                             16.5                         6.6
#
#             public_transit_commuter_pct  no_health_insurance_pct  \
# AK_01_2010                          1.2                     19.9
#
#             poverty_rate_pct  median_housing_value  median_household_income  \
# AK_01_2010               9.9                241400                  64576.0
#
#             food_stamp_benefits_pct  foreign_to_native_born_ratio
# AK_01_2010                     10.6                      0.074201
#
# [1 rows x 42 columns]

# %%
fec_demographics_imputed_data[fec_demographics_imputed_data.index == 'AK_01_2004']
# Out:
#             district state    year       party candidatevotes totalvotes  \
# AK_01_2004       1.0    AK  2004.0  republican         213216     299996
#
#             candidate  national_poll  national_poll_prev  \
# AK_01_2004  Don Young       3.680556           -0.989011
#
#             national_poll_delta_subtract              ...               \
# AK_01_2004                      4.669567              ...
#
#             foreign_born_proportion_from_LatinAmerica  \
# AK_01_2004                                       19.2
#
#            speak_other_language_at_home_pct  labor_force_unemployed_pct  \
# AK_01_2004                             16.5                         6.6
#
#             public_transit_commuter_pct  no_health_insurance_pct  \
# AK_01_2004                          1.2                     19.9
#
#             poverty_rate_pct  median_housing_value  median_household_income  \
# AK_01_2004               9.9                241400                  64576.0
#
#             food_stamp_benefits_pct  foreign_to_native_born_ratio
# AK_01_2004                     10.6                      0.074201
#
# [1 rows x 42 columns]

# %%
for col in demographics_data.columns:
    if fec_demographics_imputed_data[col].isnull().values.any():
        raise ValueError

# %%
set(fec_demographics_imputed_data['year'].values)
# Out:
# {2004.0, 2006.0, 2008.0, 2010.0, 2012.0, 2014.0, 2016.0, 2018.0}

# %%
pickle.dump(fec_demographics_imputed_data, open('Datasets/data_FEC_NATIONALPOLL_DEMOGRAPHICSIMPUTED_2004_2018.p', 'wb'))
fec_demographics_imputed_data.to_csv('Datasets/data_FEC_NATIONALPOLL_DEMOGRAPHICSIMPUTED_2004_2018.csv')
test = pickle.load(open('Datasets/data_FEC_NATIONALPOLL_DEMOGRAPHICSIMPUTED_2004_2018.p', 'rb'))
fec_demographics_imputed_data.shape, test.shape
# Out:
# ((3431, 42), (3431, 42))

# %%
set(test['year'].values)
# Out:
# {2004.0, 2006.0, 2008.0, 2010.0, 2012.0, 2014.0, 2016.0, 2018.0}

# %%
for col in demographics_data.columns:
    if test[col].isnull().values.any():
        raise ValueError

# %%
fec[fec.index == 'WI_06_2018']
# Out:
#             district state  year       party candidatevotes totalvotes  \
# WI_06_2018         6    WI  2018  republican           None       None
#
#            candidate  national_poll  national_poll_prev  \
# WI_06_2018      None       7.168919            3.175439
#
#             national_poll_delta_subtract   ...     dem_win_margin_prev  \
# WI_06_2018                       3.99348   ...                 0.37256
#
#            rep_win_margin_prev  margin_signed_minus_prev  \
# WI_06_2018            0.571547                 -0.198988
#
#             margin_signed_divide_prev  margin_unsigned_minus_prev  \
# WI_06_2018                   0.651844                    0.198988
#
#             margin_unsigned_divide_prev  dem_win_prev  rep_win_prev  dem_win  \
# WI_06_2018                     1.534109           0.0           1.0      0.0
#
#             rep_win
# WI_06_2018      1.0
#
# [1 rows x 22 columns]

# %%
demographics_data[demographics_data.index == 'WI_06_2018']
# Out:
#             female_pct  age18_24_pct  age25_34_pct  median_age  \
# WI_06_2018        49.6           8.9          11.5        42.1
#
#             unmarried_partner_pct  male_living_alone_pct  \
# WI_06_2018                    3.1                   13.4
#
#             bachelors_deg_or_higher_pct  \
# WI_06_2018                         26.8
#
#            past_year_births_to_unmarried_women_pct  civilian_veteran_pct  \
# WI_06_2018                                    23.9                   7.8
#
#             live_same_house_past_year_pct  \
# WI_06_2018                           86.0
#
#             foreign_born_proportion_from_LatinAmerica  \
# WI_06_2018                                       33.5
#
#             speak_other_language_at_home_pct  labor_force_unemployed_pct  \
# WI_06_2018                               6.9                         1.9
#
#             public_transit_commuter_pct  no_health_insurance_pct  \
# WI_06_2018                          0.5                      4.6
#
#             poverty_rate_pct median_housing_value  median_household_income  \
# WI_06_2018               8.8               163500                    59685
#
#             food_stamp_benefits_pct  foreign_to_native_born_ratio
# WI_06_2018                      9.5                      0.037647

# %%
fec_demographics_data[fec_demographics_data.index == 'WI_06_2018']
# Out:
#             district state  year       party candidatevotes totalvotes  \
# WI_06_2018         6    WI  2018  republican           None       None
#
#            candidate  national_poll  national_poll_prev  \
# WI_06_2018      None       7.168919            3.175439
#
#             national_poll_delta_subtract              ...               \
# WI_06_2018                       3.99348              ...
#
#             foreign_born_proportion_from_LatinAmerica  \
# WI_06_2018                                       33.5
#
#            speak_other_language_at_home_pct  labor_force_unemployed_pct  \
# WI_06_2018                              6.9                         1.9
#
#             public_transit_commuter_pct  no_health_insurance_pct  \
# WI_06_2018                          0.5                      4.6
#
#             poverty_rate_pct  median_housing_value  median_household_income  \
# WI_06_2018               8.8                163500                    59685
#
#             food_stamp_benefits_pct  foreign_to_native_born_ratio
# WI_06_2018                      9.5                      0.037647
#
# [1 rows x 42 columns]

# %%
test.columns
# Out:
# Index(['district', 'state', 'year', 'party', 'candidatevotes', 'totalvotes',
#        'candidate', 'national_poll', 'national_poll_prev',
#        'national_poll_delta_subtract', 'national_poll_delta_divide',
#        'previous_party', 'dem_win_margin_prev', 'rep_win_margin_prev',
#        'margin_signed_minus_prev', 'margin_signed_divide_prev',
#        'margin_unsigned_minus_prev', 'margin_unsigned_divide_prev',
#        'dem_win_prev', 'rep_win_prev', 'dem_win', 'rep_win', 'female_pct',
#        'age18_24_pct', 'age25_34_pct', 'median_age', 'unmarried_partner_pct',
#        'male_living_alone_pct', 'bachelors_deg_or_higher_pct',
#        'past_year_births_to_unmarried_women_pct', 'civilian_veteran_pct',
#        'live_same_house_past_year_pct',
#        'foreign_born_proportion_from_LatinAmerica',
#        'speak_other_language_at_home_pct', 'labor_force_unemployed_pct',
#        'public_transit_commuter_pct', 'no_health_insurance_pct',
#        'poverty_rate_pct', 'median_housing_value', 'median_household_income',
#        'food_stamp_benefits_pct', 'foreign_to_native_born_ratio'],
#       dtype='object')

# %%
fec.shape
# Out:
# (3431, 22)

# %%
demographics_data.shape

# %%
demographics_data.columns
