# %%
#imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# %load functions/demographicsFunctions.py

# %%
data_df_MA= read_cols_light("Datasets/Massachusetts_District_all.csv", "MA", "2008")
data_df_MA.head()
# Out:
#                         Male  Female American Indian and Alaska Native  Asian  \
# District 01 Estimate  353352  383108                              2139  18117
# District 02 Estimate  363325  380799                              2782  42773
# District 03 Estimate  384419  384696                              1662  64549
# District 04 Estimate  361348  390729                               328  44842
# District 05 Estimate  369701  396509                              1287  94637
#
#                      Black or African American  \
# District 01 Estimate                     47737
# District 02 Estimate                     40734
# District 03 Estimate                     26471
# District 04 Estimate                     26409
# District 05 Estimate                     46371
#
#                      Native Hawaiian and Other Pacific Islander One race  \
# District 01 Estimate                                         56   716681
# ...
